# %%
#Import Necessary Libraries

import pandas as pd
import os

# %%
#Merge .xlsx files into one .xlsx file

files = [file for file in os.listdir("./Accounts")]
all_accounts = pd.DataFrame()
for file in files:
    df = pd.read_excel("./Accounts/"+file)
    all_accounts = pd.concat([all_accounts, df], sort = True)
all_accounts.to_csv("all_data.csv", index = False)

# %%
all_data = pd.read_csv("all_data.csv")
all_data.head()
# Out:
#          .1  .10  .11  .12  .13   .2   .3   .4   .5  ... Unnamed: 24  \
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...         NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...         NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...         NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...
#
#    Unnamed: 3            Unnamed: 4     Unnamed: 5       Unnamed: 6  \
# 0         NaN                   NaN            NaN              NaN
# 1         NaN                   NaN            NaN              NaN
# 2       datum  VremePotvrdeIsporuke  PosiljalacIme  PosiljalacMesto
# 3  30.10.2019  01.11.2019. 16:52:08        EURO 07           NIS NI
# 4  31.10.2019  01.11.2019. 16:45:35        EURO 07           NIS NI
#
#     Unnamed: 7     Unnamed: 8  Unnamed: 9 VremePotvrdeIsporuke datum
# 0          NaN            NaN         NaN                  NaN   NaN
# 1          NaN            NaN         NaN                  NaN   NaN
# 2  PrimalacIme  PrimalacMesto  UkupnaCena                  NaN   NaN
# 3  EURO 07 DOO  NOVI PAZAR NP         240                  NaN   NaN
# 4  EURO 07 DOO       ZEMUN ZE         900                  NaN   NaN
#
# [5 rows x 52 columns]

# %%
#Making a usufol header
all_data = all_data.drop([0, 1], axis=0)
new_header = all_data.iloc[0]
all_data = all_data[1:]
all_data.columns = new_header
all_data.head()
# Out:
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ... NaN       datum  \
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...      30.10.2019
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...      31.10.2019
# 5  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...      31.10.2019
# 6  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...      31.10.2019
# 7  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...      31.10.2019
#
# 2  VremePotvrdeIsporuke PosiljalacIme PosiljalacMesto        PrimalacIme  \
# 3  01.11.2019. 16:52:08       EURO 07          NIS NI        EURO 07 DOO
# 4  01.11.2019. 16:45:35       EURO 07          NIS NI        EURO 07 DOO
# 5  01.11.2019. 15:27:11       EURO 07          NIS NI        EURO 07 DOO
# 6  01.11.2019. 20:29:43       EURO 07          NIS NI  EURO 07 DOO ZEMUN
# 7  01.11.2019. 16:58:39       EURO 07          NIS NI        EURO 07 DOO
#
# 2  PrimalacMesto  UkupnaCena  NaN  NaN
# 3  NOVI PAZAR NP         240  NaN  NaN
# 4       ZEMUN ZE         900  NaN  NaN
# 5     KRAGUJEVAC         780  NaN  NaN
# 6       ZEMUN ZE         540  NaN  NaN
# 7    VETERNIK NS         540  NaN  NaN
#
# [5 rows x 52 columns]
